# %%
import numpy as np
import scipy as sp
from scipy.integrate import odeint

import matplotlib.pyplot as plt
from IPython.display import Latex
from IPython.html.widgets import interactive
# %pylab inline --no-import-all
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/schultzk/anaconda/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
N=10000
y=np.zeros([4])
Lo=.5
L=1.
vo=1.4
thetao=np.pi/2
omegao=1.
beta=0.
b=2

# %%
y[0]=L
y[1]=vo
y[2]=thetao
y[3]=omegao

# %%
time=np.linspace(0,1000,N)

# %%
k=2.5
m=.2
gravity=9.8

# %%
def spring_pendulum(y,time):
    g0=y[1]
    g1=Lo+y[0]*y[3]*y[3]-k/m*y[0]+gravity*np.cos(y[2])
    g2=y[3]
    g3=-(gravity*np.sin(y[2])+2.0*y[1]*y[3])/(Lo+y[0])
    return np.array([g0,g1,g2,g3])

# %%
answer=odeint(spring_pendulum,y,time)

# %%
xdata=(Lo+answer[:,0])*np.sin(answer[:,2])
ydata=-(Lo+answer[:,0])*np.cos(answer[:,2])

# %%
fig, ax=plt.subplots()
ax.plot(xdata,ydata)

# %%
def damped_driven_pendulum(state,time):
    g0=state[1]
    g1=-gravity/Lo*np.sin(state[0])-b*state[1]+beta*np.cos(omegao*time/3.)
    return np.array([g0,g1])

# %%
state=np.zeros(2)
state[0]=thetao
state[1]=omegao
answer=odeint(damped_driven_pendulum,state,time)

# %%
fig,ax=plt.subplots()
ax.plot(answer[:,0],answer[:,1])

# %%
skip=100
answer=answer[skip*]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ca94444d24bc> in <module>()
# ----> 1 show()
#
# NameError: name 'show' is not defined

# %%
# x''' +Ax'' -x'^2+x=0
# x'=v
# v'=a
# a'=-Av'+v^2-x

def jerk(state,time):
    g0=state[1]
    g1=state[2]
    g2=-A*state[2]+state[1]**2-state[0]
    return np.array([g0,g1,g2])

# %%
def jerk2(state,time):
    g0=state[1]
    g1=state[2]
    g2=-state[1]+state[0]**2-B
    return np.array([g0,g1,g2])

# %%
A=2.017
B=2.2
xo=.4
vo=-.4
ao=.3
vector=np.zeros(3)
vector[0]=xo
vector[1]=vo
vector[2]=ao
N=1000000
time=np.linspace(0,1000,N)

# %%
answer=odeint(jerk,vector,time)

# %%
fig, ax=plt.subplots()
ax.plot(answer[:,0],answer[:,1])
ax.plot(xo,vo,'x')

# %%
plot(time,answer[:,2])
show()

# %%
A=2.017
B=.01
xo=0
vo=-.001
ao=0
vector=np.zeros(3)
vector[0]=xo
vector[1]=vo
vector[2]=ao
N=5000
time=np.linspace(0,500,N)

# %%
answer=odeint(jerk2,vector,time)

fig,ax=plt.subplots()
ax.plot(answer[:,0],answer[:,1])

# %%
A=2.017
B=.01
xo=0.
vo=-.001
ao=0.
vector=np.zeros(3)
vector[0]=xo
vector[1]=vo
vector[2]=ao
N=50000000
time=np.linspace(0,5000,N)
fig, ax=plt.subplots()
vo=np.linspace(-.1,0,50)
for j in vo:
    P=[]
    
   
    vector[1]=j
    answer=odeint(jerk2,vector,time)
    
    
    
    for i in range(len(answer[:,1])-2):
        test=answer[i,2]*answer[i+1,2]
        if test<0:
            P.append((answer[i,0],answer[i,1]))
            
   
    ax.plot(np.array(P)[:,1],np.array(P)[:,0],'.',markersize=1)
    plt.ylim(-.2,.2)
    plt.xlim(-.2,.2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-07e64f5195d0> in <module>()
#      22
#      23     for i in range(len(answer[:,1])-2):
# ---> 24         test=answer[i,2]*answer[i+1,2]
#      25         if test<0:
#      26             P.append((answer[i,0],answer[i,1]))
#
# KeyboardInterrupt:

# %%
def diode(x):
    return -6*min(x,0)

# %%
def sprott_ckt(state,time,Rv):
    g0=state[1]
    g1=state[2]
    g2=-(R/Rv)*state[2]-state[1]+diode(state[0])-(R/Ro)*Vo
    return np.array([g0,g1,g2])

# %%
R=47e3
Ro=157e3
Rv=200e3
Vo=.253
vector=np.zeros(3)
vector[0]=.75
vector[1]=0.
vector[2]=0
N=50000
time=np.linspace(0,1000,N)

# %%
answer=odeint(sprott_ckt,vector,time,args=(Rv,))

fig,ax=plt.subplots()
ax.plot(answer[:,0],answer[:,1])

# %%
fig, ax=plt.subplots()
ax.plot(time[-1000:],answer[-1000:,0],',')

# %%
from scipy.signal import argrelextrema

# %%
c=answer[-5000:,0]
a=c[argrelextrema(c,np.greater)[0]]
r=np.full((len(a),1), Rv)
fig, ax = plt.subplots()
ax.plot(r,a,',k')
plt.ylim(0,.5)
a
# Out:
# array([ 1.16684419,  1.16690816,  1.1668557 ,  1.16689909,  1.16686401,
#         1.16688672,  1.1668685 ,  1.16687856,  1.16686911,  1.16688875,
#         1.16686702,  1.16689494,  1.16686145,  1.16689877,  1.16685139,
#         1.16689929])

# %%
Rv=np.linspace(50e3,250e3,1000)
fig, ax = plt.subplots()
for i in Rv:
    answer=odeint(sprott_ckt,vector,time,args=(i,))
    c=answer[-5000:,0]
    a=c[argrelextrema(c,np.greater)[0]]
    r=np.full((len(a),1), i)
    ax.plot(r,a,',k')

# %%
vo
# Out:
# array([ -1.00000000e-03,  -9.79591837e-04,  -9.59183673e-04,
#         -9.38775510e-04,  -9.18367347e-04,  -8.97959184e-04,
#         -8.77551020e-04,  -8.57142857e-04,  -8.36734694e-04,
#         -8.16326531e-04,  -7.95918367e-04,  -7.75510204e-04,
#         -7.55102041e-04,  -7.34693878e-04,  -7.14285714e-04,
#         -6.93877551e-04,  -6.73469388e-04,  -6.53061224e-04,
#         -6.32653061e-04,  -6.12244898e-04,  -5.91836735e-04,
#         -5.71428571e-04,  -5.51020408e-04,  -5.30612245e-04,
#         -5.10204082e-04,  -4.89795918e-04,  -4.69387755e-04,
#         -4.48979592e-04,  -4.28571429e-04,  -4.08163265e-04,
#         -3.87755102e-04,  -3.67346939e-04,  -3.46938776e-04,
#         -3.26530612e-04,  -3.06122449e-04,  -2.85714286e-04,
#         -2.65306122e-04,  -2.44897959e-04,  -2.24489796e-04,
#         -2.04081633e-04,  -1.83673469e-04,  -1.63265306e-04,
#         -1.42857143e-04,  -1.22448980e-04,  -1.02040816e-04,
#         -8.16326531e-05,  -6.12244898e-05,  -4.08163265e-05,
#         -2.04081633e-05,   0.00000000e+00])

# %%
steps=1000
theta_initial=np.pi/6.0
v_initial=0.0
omega=1.0
beta=0.5
amp=1.2
omega_d=0.713
time_step=2.0*np.pi/(omega_d*steps)

# %%
N=300
skip=100

# %%
initial_state=np.array([theta_initial,v_initial])

# %%
time=np.arange(0.,N*(2.0*np.pi)/omega_d,time_step)

# %%
answer=odeint(damped_driven_pendulum,initial_state,time)

# %%
answer=answer[skip*steps:]
