# %% [markdown]
# # RK4

# %%
from numpy import sin,cos ,arange,zeros,empty,array,pi,linspace
from numpy.random import normal
from pylab import plot, xlabel, ylabel, show,xlim, ylim

# %%
def f(x,t,*karg):
    return -x**3+sin(t)
# using the *karg allows us to send more parameters if we wish. The code below
# is for a function for dv/dt=-bv-9.8, which simulates drag

# %%
def rk4(x0,tpoints):
    h=(tpoints[1]-tpoints[0])
    N=len(tpoints)
    vpoints=zeros(N,float) #This is just an array to store f, which by definition is dx/dt
                            # It sometimes is useful to have this info, but can easily be 
                            #commented out
    xpoints=zeros(N,float)  #Store our solution in an array. Arrays are much more flexible
                            # than lists in what we do
    xpoints[0]=x0            # set the intitial condition to the first point in solution
    for i, t in enumerate(tpoints[:-1]): #enumerate allows us to get both the value of an array
                                    # and the indicies
        x=xpoints[i]
        k1=h*f(x,t)
        k2=h*f(x+.5*k1,t+.5*h)
        k3=h*f(x+.5*k2,t+.5*h)
        k4=h*f(x+k3, t+h)
        xpoints[i+1]=xpoints[i]+(k1+2*k2+2*k3+k4)/6
        vpoints[i]=f(x,t)
    return xpoints,vpoints

# %%
#set up our time array
t0=0.       #a in the book, but this makes more sense
tf=30.0   # b in the book, but this makes more sense
N=100      # number of points to integrate
h=(tf-t0)/N   #step size
tpoints=arange(t0,tf,h)
x0=0

solution,vel=rk4(x0,tpoints)
plot(tpoints,solution)
show()

# %%
#plot the velocity field
plot(tpoints,f(0,tpoints),"bx")
show()

# %% [markdown]
# the function rk4v2 below allows one to send arguments along to f. This is useful, if you want to iterate through particular constants.

# %%
def f(x,t,*karg):
    if len(karg)!=0:
        b=karg[0]
    else:
        b=0
    return(b*x**2-9.8)

# %%
def rk4v2(x0,tpoints,*argv):
    """*argv here sends info onto f(x,argv)"""
    h=tpoints[1]-tpoints[0]
    N=len(tpoints)
    vpoints=zeros(N,float)
    xpoints=zeros(N,float)
    xpoints[0]=x0
    for i,t in enumerate(tpoints[:-1]):
        
        k1=h*f(xpoints[i],t,*argv)
        k2=h*f(xpoints[i]+.5*k1,t+.5*h,*argv)
        k3=h*f(xpoints[i]+.5*k2,t+.5*h,*argv)
        k4=h*f(xpoints[i]+k3, t+h,*argv)
        xpoints[i+1]=xpoints[i]+(k1+2*k2+2*k3+k4)/6
        vpoints[i]=f(xpoints[i],t,*argv)
    return xpoints,vpoints

# %%
x,v=rk4v2(1,tpoints,0)
plot(tpoints,x)
show()

# %% [markdown]
# One can loop through the drag coeffficient to plot a series of solutions

# %%
drag_coeff=(0,.1,.5,1,2)
for b in drag_coeff:
    x,v=rk4v2(1,tpoints,b)
    plot(tpoints,x)
ylim(-20,1)  
show()

# %% [markdown]
# What follows below is a version of rk4 that allows us to loop through different initial conditions.

# %%
def f(x,t,*karg):
    return -x**3+sin(t)

# %%
def rk4v3(tpoints,*argv):
    """*argv here is used to loop through different intital conditions"""
    h=tpoints[1]-tpoints[0]
    N=len(tpoints)
    vpoints=zeros(N,float)
    xpoints=zeros(N,float)
    if len(argv)!=0:
        xpoints[0]=argv[0]
    else: xpoints[0]=0    
    for i,t in enumerate(tpoints[:-1]):
        
        k1=h*f(xpoints[i],t)
        k2=h*f(xpoints[i]+.5*k1,t+.5*h)
        k3=h*f(xpoints[i]+.5*k2,t+.5*h)
        k4=h*f(xpoints[i]+k3, t+h)
        xpoints[i+1]=xpoints[i]+(k1+2*k2+2*k3+k4)/6
        vpoints[i]=f(xpoints[i],t)
    return xpoints,vpoints

# %%
x0=[0.5,0.4,0.3,-.1]
for l in x0:
    x,v=rk4v3(tpoints,l)
    plot(v,x)
    plot(tpoints[0],l,"o")
xlabel("x")
ylabel("dy/dt")
show()

# %% [markdown]
# Below is a function for the Lotke-volterra equations. These are two coupled eqauations
# \begin{align}\frac{dx}{dt}&=\alpha x-\beta x y\\
# \frac{dy}{dy}&=\gamma x y- \delta y
# \end{align}
#
# We send $x$ and $y$ variables as a vector and send back an array. Yay, Python!

# %%
def f2(r,t,*args):
    
    if len(args)!=0:
        alpha=args[0]
        beta=args[1]
        gamma=args[2]
        delta=args[3]
    else:
        alpha=1.
        beta=0.5
        gamma=0.5
        delta=2.
    x=r[0]
    y=r[1]
    fx=alpha*x*-beta*x*y
    fy=gamma*x*y-delta*y
    return array([fx,fy])

# %% [markdown]
# Below is the modification of rk4 that allows for multiple simultaneous equations

# %%
def rk4v4(ic,tpoints,*argv):
    N=len(tpoints)
    ypoints=zeros(N,float)
    xpoints=zeros(N,float)
    xpoints[0]=ic[0]
    ypoints[1]=ic[1]
    r=ic

    h=tpoints[1]-tpoints[0]
    
   
    for i,t in enumerate(tpoints[:-1]):
        
        k1=h*f2(r,t,*argv)
        k2=h*f2(r+.5*k1,t+.5*h,*argv)
        k3=h*f2(r+.5*k2,t+.5*h,*argv)
        k4=h*f2(r+k3, t+h,*argv)
        r+=(k1+2*k2+2*k3+k4)/6
        xpoints[i+1]=r[0]
        ypoints[i+1]=r[1]
    return array([xpoints,ypoints])

# %%
#set up our time array
t0=0.       #a in the book, but this makes more sense
tf=40.0   # b in the book, but this makes more sense
N=1000      # number of points to integrate
h=(tf-t0)/N   #step size
tpoints=arange(t0,tf,h)
x0=0
LV_constants=(1,.5,.5,2)
sol=rk4v4([2,2],tpoints)

# %%
plot(tpoints,sol[0])


show()

# %%
beta=(1,2,.3,4,.5)
for b in beta:
    LV_constants=(1,b,b,2)
    sol=rk4v4([1,2],tpoints,*LV_constants)
    plot(tpoints,sol[1])
show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-a7ae4909978e> in <module>()
#       2 for b in beta:
#       3     LV_constants=(1,b,b,2)
# ----> 4     sol=rk4v4([1,2],tpoints,*LV_constants)
#       5     plot(tpoints,sol[1])
#       6 show()
#
# <ipython-input-79-7259ef57163c> in rk4v4(ic, tpoints, *argv)
#      12     for i,t in enumerate(tpoints[:-1]):
#      13
# ---> 14         k1=h*f2(r,t,*argv)
#      15         k2=h*f2(r+.5*k1,t+.5*h,*argv)
#      16         k3=h*f2(r+.5*k2,t+.5*h,*argv)
#
# TypeError: f2() takes 2 positional arguments but 6 were given

# %%
def f2(r,t):
    g=9.81
    k=3.5
    m=.2
    x=r[0]
    
    v=r[1]
    dx=v
    dv=-k/m*x-g
    return array([dx,dv],float)

# %%
sol=rk4v4([-1,0],tpoints)

# %%
plot(tpoints,sol[0])
plot(tpoints,sol[1])
xlabel("time")
ylabel("x,v")
show()

# %%
plot(sol[0],sol[1])
show()

# %%
#set up our time array
t0=0.       #a in the book, but this makes more sense
tf=10.0   # b in the book, but this makes more sense
N=1000      # number of points to integrate
h=(tf-t0)/N   #step size
tpoints=arange(t0,tf,h)
x0=0.

# %%
a=(1,2,3,4)

# %%
a[0]
# Out:
# 1

# %%
a[1]
# Out:
# 2

# %%
a[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-750-4a84d856522b> in <module>()
# ----> 1 a[5]
#
# IndexError: tuple index out of range

# %%
def f2(r,t):
    x=r[0]
    
    y=r[1]
    dx=-4*x-3*y
    dy=2*x+3*y
    return array([dx,dy],float)

# %%
#set up our time array
t0=0.       #a in the book, but this makes more sense
tf=1.0   # b in the book, but this makes more sense
N=100    # number of points to integrate
h=(tf-t0)/N   #step size
tpoints=arange(t0,tf,h)
sol=rk4v4([-1,0],tpoints)

# %%
plot(sol[0],sol[1])
show()

# %%
for n in range(500):
    x0=normal()
    y0=normal()
    sol=rk4v4([x0,y0],tpoints)
    plot(sol[0,1:],sol[1,1:])
    plot(x0,y0)
xlim(-1,1)
ylim(-1,1)
show()

# %%
y1=linspace(-1,1,10)
y2=linspace(-1,1,10)
U,V=f2([y1,y2],0)

# %%
from pylab import quiver
quiver(y1,y2,U,V)
